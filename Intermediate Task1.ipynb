# %% [markdown]
# # LGM-VIP Data Science Internship Programme Intermediate Level Task-1 Exploratory data Analysis on Terrorism Submitted by Pratiksha Shinde

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
terr = pd.read_csv('D:\global.csv', encoding='iso-8859-1')

# %%
terr.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
terr.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
terr.shape
# Out:
# (181691, 135)

# %%
terr.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
terr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
terr.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
terr.isnull().sum()/terr.isnull().count()
# Out:
# eventid       0.000000
# iyear         0.000000
# imonth        0.000000
# iday          0.000000
# approxdate    0.949150
#                 ...
# INT_LOG       0.000000
# INT_IDEO      0.000000
# INT_MISC      0.000000
# INT_ANY       0.000000
# related       0.862195
# Length: 135, dtype: float64

# %%
terr.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
terr.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country',
                    'provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType',
                    'target1':'Target','nkill':'Killed','nwound':'Wounded','gname':'Group',
                    'summary':'Summary','targtype1_txt':'TargetType','weaptype1_txt':'WeaponType',
                    'motive':'Motive','city':'City','latitude':'Latitude','longitude':'Longitude'}, inplace=True)

# %%
terr = terr[['Year','Month','Day','Country','State','Region','City','Latitude','Longitude','AttackType',
            'Killed','Wounded','Target','Summary','Group','TargetType','WeaponType','Motive']]

# %%
terr.shape
# Out:
# (181691, 18)

# %%
terr.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded
# count  1.771340e+05  171378.000000  165380.000000
# mean  -4.586957e+02       2.403272       3.167668
# std    2.047790e+05      11.545741      35.949392
# min   -8.618590e+07       0.000000       0.000000
# 25%    4.545640e+00       0.000000       0.000000
# 50%    4.324651e+01       0.000000       0.000000
# ...

# %%
terr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 18 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Year        181691 non-null  int64
#  1   Month       181691 non-null  int64
#  2   Day         181691 non-null  int64
#  3   Country     181691 non-null  object
#  4   State       181270 non-null  object
#  5   Region      181691 non-null  object
#  6   City        181257 non-null  object
#  7   Latitude    177135 non-null  float64
#  8   Longitude   177134 non-null  float64
#  9   AttackType  181691 non-null  object
#  10  Killed      171378 non-null  float64
#  11  Wounded     165380 non-null  float64
#  12  Target      181055 non-null  object
#  13  Summary     115562 non-null  object
#  14  Group       181691 non-null  object
#  15  TargetType  181691 non-null  object
#  16  WeaponType  181691 non-null  object
#  17  Motive      50561 non-null   object
# ...

# %%
terr.isnull().sum()/terr.isnull().count()
# Out:
# Year          0.000000
# Month         0.000000
# Day           0.000000
# Country       0.000000
# State         0.002317
# Region        0.000000
# City          0.002389
# Latitude      0.025076
# Longitude     0.025081
# AttackType    0.000000
# Killed        0.056761
# Wounded       0.089773
# Target        0.003500
# Summary       0.363964
# Group         0.000000
# TargetType    0.000000
# WeaponType    0.000000
# Motive        0.721720
# dtype: float64

# %%
terr = terr.drop('Motive', axis = 1)
terr.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
terr.shape
# Out:
# (181691, 17)

# %% [markdown]
# Correlation Matrix

# %%
plt.figure(figsize=(15,10))
cor = terr.corr()
sns.heatmap(cor, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Number of Terrorists Attacks ratio to Countries

# %%
plt.figure(figsize=(50,10))
sns.countplot(terr['Country'],palette="magma")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Number of Terrorist attacks yearwise

# %%
plt.figure(figsize=(10,10))
sns.countplot(terr['Year'], palette='viridis')
plt.title('Number of Terrorist Attacks per Year',fontsize='20')
plt.ylabel("Number of attacks")
plt.xlabel("Year")
plt.xticks(rotation='40')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title('Top 10 Affected Regions',fontsize='20')
terr['Region'].value_counts().head(10).plot(kind='pie',autopct='%.01f%%')
plt.show()

# %%
terr_india = terr[terr['Country'] == 'India']['State']
plt.figure(figsize=(20,10))
sns.barplot(terr_india.value_counts()[:10].index, terr_india.value_counts()[:10].values)
plt.title('Top 10 Affected States of India',fontsize='20')
plt.xlabel('States',fontsize='20')
plt.ylabel('Count',fontsize='20')
plt.xticks(rotation='30')
plt.show()

# %% [markdown]
# Attack type

# %%
plt.figure(figsize=(20,10))
terr['AttackType'].value_counts().plot(kind='pie',autopct='%.01f%%')
plt.title('Type of attack', fontsize='20')
plt.show()

# %% [markdown]
# Type of Targets

# %%
plt.subplots(figsize=(10,10))
sns.countplot(terr["TargetType"],order=terr['TargetType'].value_counts().index, palette="viridis");
plt.xticks(rotation=30)
plt.xlabel("Target type",fontsize=15)
plt.ylabel("Number of attacks",fontsize=15)
plt.title("Most preferred target types",fontsize=20)
plt.show()

# %% [markdown]
# Involved Terrorist Groups

# %% [markdown]
# plt.figure(figsize=(20,10))
# sns.barplot(terr['Group'].value_counts()[1:10].index,terr['Group'].value_counts()[1:10].values,)
# plt.title('Most Involved Terrorist Groups',fontsize='20')
# plt.xlabel('Terrorist Group')
# plt.ylabel('Count')
# plt.xticks(rotation='50')
# plt.show()
